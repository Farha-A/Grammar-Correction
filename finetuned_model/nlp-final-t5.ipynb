# %%
import pandas as pd
from tqdm import tqdm
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from torch.cuda.amp import autocast, GradScaler

# Custom Dataset class for grammar correction
class GrammarCorrectionDataset(Dataset):
    def __init__(self, inputs, targets, tokenizer, max_length=128, model_type='t5'):
        self.inputs = inputs
        self.targets = targets
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.model_type = model_type
    
    def __len__(self):
        return len(self.inputs)
    
    def __getitem__(self, idx):
        input_text = str(self.inputs[idx])
        target_text = str(self.targets[idx])
        
        # Tokenize inputs
        input_encoding = self.tokenizer(
            input_text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )
        
        # Tokenize targets
        target_encoding = self.tokenizer(
            target_text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )
        
        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask': input_encoding['attention_mask'].squeeze(),
            'labels': target_encoding['input_ids'].squeeze()
        }

# Function to train and evaluate T5 model
def train_and_evaluate(model, tokenizer, train_loader, val_loader, device, model_name, num_epochs=1, accum_steps=2):
    optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
    scaler = GradScaler()
    
    # Function to calculate cosine similarity
    def calculate_cosine_similarity(predicted, target, model, tokenizer):
        with torch.no_grad():
            pred_emb = model.get_encoder()(input_ids=predicted.unsqueeze(0).to(device)).last_hidden_state.mean(dim=1).cpu().numpy()
            target_emb = model.get_encoder()(input_ids=target.unsqueeze(0).to(device)).last_hidden_state.mean(dim=1).cpu().numpy()
        return cosine_similarity(target_emb,pred_emb )[0][0]

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        total_train_acc = 0
        optimizer.zero_grad()
        for i, batch in enumerate(tqdm(train_loader, desc=f"{model_name} Training Epoch {epoch+1}")):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            
            with autocast():
                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    labels=labels
                )
                
                loss = outputs.loss / accum_steps
                train_loss += loss.item() * accum_steps
            
            scaler.scale(loss).backward()
            
            if (i + 1) % accum_steps == 0:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()
            
            preds = torch.argmax(outputs.logits, dim=-1)
            total_train_acc += (preds == labels).sum().item() / torch.numel(labels)
        
        avg_train_loss = train_loss / len(train_loader)
        avg_train_acc = total_train_acc / len(train_loader)
        print(f"{model_name} Epoch {epoch+1} Training Loss: {avg_train_loss:.4f}")
        print(f"{model_name} Epoch {epoch+1} Training Accuracy: {avg_train_acc:.4f}")
        
        # Validation
        model.eval()
        val_loss = 0
        total_val_acc = 0
        val_similarities = []
        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"{model_name} Validation Epoch {epoch+1}"):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)
                
                with autocast():
                    outputs = model(
                        input_ids=input_ids,
                        attention_mask=attention_mask,
                        labels=labels
                    )
                
                val_loss += outputs.loss.item()
                
                preds = torch.argmax(outputs.logits, dim=-1)
                total_val_acc += (preds == labels).sum().item() / torch.numel(labels)
                
                for i in range(input_ids.size(0)):
                    pred_ids = model.generate(
                        input_ids[i].unsqueeze(0),
                        max_length=128,
                        num_beams=5,
                        early_stopping=True,
                        no_repeat_ngram_size=2
                    )
                    similarity = calculate_cosine_similarity(pred_ids[0], labels[i], model, tokenizer)
                    val_similarities.append(similarity)
        
        avg_val_loss = val_loss / len(val_loader)
        avg_val_acc = total_val_acc / len(val_loader)
        avg_val_similarity = np.mean(val_similarities) if val_similarities else 0
        print(f"{model_name} Epoch {epoch+1} Validation Loss: {avg_val_loss:.4f}")
        print(f"{model_name} Epoch {epoch+1} Validation Accuracy: {avg_val_acc:.4f}")
        print(f"{model_name} Epoch {epoch+1} Validation Cosine Similarity: {avg_val_similarity:.4f}")
    
    # Save fine-tuned model
    model.save_pretrained(f"./fine_tuned_{model_name.lower()}")
    tokenizer.save_pretrained(f"./fine_tuned_{model_name.lower()}")

# Load dataset
n_rows = 10000
df = pd.read_csv('/kaggle/input/c4200m/C4_200M.tsv-00007-of-00010', sep='\t', nrows=n_rows)
df.columns = ["input", "target"]

# Display sample
print("Sample input:", df["input"][150])
print("Sample target:", df["target"][150])

# Initialize T5
t5_tokenizer = T5Tokenizer.from_pretrained("t5-large")
t5_model = T5ForConditionalGeneration.from_pretrained("t5-large")

# Prepare datasets
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)

# T5 datasets
t5_train_dataset = GrammarCorrectionDataset(
    inputs=train_df["input"].tolist(),
    targets=train_df["target"].tolist(),
    tokenizer=t5_tokenizer,
    model_type='t5'
)
t5_val_dataset = GrammarCorrectionDataset(
    inputs=val_df["input"].tolist(),
    targets=val_df["target"].tolist(),
    tokenizer=t5_tokenizer,
    model_type='t5'
)

# Create data loaders
batch_size = 4
t5_train_loader = DataLoader(t5_train_dataset, batch_size=batch_size, shuffle=True)
t5_val_loader = DataLoader(t5_val_dataset, batch_size=batch_size)

# Training setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
t5_model.to(device)

# Train and evaluate T5 model
train_and_evaluate(t5_model, t5_tokenizer, t5_train_loader, t5_val_loader, device, "T5", accum_steps=2)

# Test T5 model
def test_model(model, tokenizer, text, model_type, device):
    model.eval()
    input_text = text
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=128, num_beams=5, early_stopping=True, no_repeat_ngram_size=2)
    corrected = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return corrected

# Test example
test_input = df["input"][550]
print("\nTest Example:")
print("Input:", test_input)
print("T5 Corrected Output:", test_model(t5_model, t5_tokenizer, test_input, 't5', device))
print("Target:", df["target"][550])
# Out:
# 2025-05-10 10:36:42.825599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746873403.005076      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746873403.056359      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sample input: Fiber Optic Cable Cleaning Kits The complete solution for precision end face - Fiber optic cable cleaning.
# Sample target: Fiber Optic Cable Cleaning Kits The complete solution for precision end-face fiber optic cable cleaning.
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# /tmp/ipykernel_31/2906084304.py:54: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# T5 Training Epoch 1:   0%|          | 0/2250 [00:00<?, ?it/s]/tmp/ipykernel_31/2906084304.py:73: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# T5 Training Epoch 1: 100%|██████████| 2250/2250 [18:55<00:00,  1.98it/s]
# T5 Epoch 1 Training Loss: nan
# T5 Epoch 1 Training Accuracy: 0.7303
# T5 Validation Epoch 1:   0%|          | 0/250 [00:00<?, ?it/s]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   0%|          | 1/250 [00:15<1:03:51, 15.39s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   1%|          | 2/250 [00:27<54:55, 13.29s/it]  /tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   1%|          | 3/250 [00:42<58:19, 14.17s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   2%|▏         | 4/250 [00:57<59:41, 14.56s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   2%|▏         | 5/250 [01:12<1:00:24, 14.79s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   2%|▏         | 6/250 [01:27<1:00:39, 14.92s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   3%|▎         | 7/250 [01:39<56:21, 13.92s/it]  /tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   3%|▎         | 8/250 [01:54<57:45, 14.32s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   4%|▎         | 9/250 [02:10<58:47, 14.64s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   4%|▍         | 10/250 [02:25<59:11, 14.80s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   4%|▍         | 11/250 [02:34<51:31, 12.93s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   5%|▍         | 12/250 [02:49<54:02, 13.63s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   5%|▌         | 13/250 [02:59<49:30, 12.53s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   6%|▌         | 14/250 [03:14<52:17, 13.30s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   6%|▌         | 15/250 [03:29<54:20, 13.87s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   6%|▋         | 16/250 [03:45<55:56, 14.35s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   7%|▋         | 17/250 [04:00<56:41, 14.60s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   7%|▋         | 18/250 [04:15<57:14, 14.80s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   8%|▊         | 19/250 [04:30<57:28, 14.93s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   8%|▊         | 20/250 [04:46<57:42, 15.06s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   8%|▊         | 21/250 [04:59<54:56, 14.39s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   9%|▉         | 22/250 [05:14<55:27, 14.59s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:   9%|▉         | 23/250 [05:29<55:48, 14.75s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  10%|▉         | 24/250 [05:44<56:02, 14.88s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  10%|█         | 25/250 [05:59<56:09, 14.97s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  10%|█         | 26/250 [06:14<56:00, 15.00s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  11%|█         | 27/250 [06:28<54:58, 14.79s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  11%|█         | 28/250 [06:43<55:01, 14.87s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  12%|█▏        | 29/250 [06:59<55:23, 15.04s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  12%|█▏        | 30/250 [07:14<55:18, 15.08s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  12%|█▏        | 31/250 [07:29<55:20, 15.16s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  13%|█▎        | 32/250 [07:45<55:10, 15.19s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  13%|█▎        | 33/250 [07:57<51:40, 14.29s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  14%|█▎        | 34/250 [08:12<52:16, 14.52s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  14%|█▍        | 35/250 [08:24<49:23, 13.78s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  14%|█▍        | 36/250 [08:36<46:44, 13.10s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  15%|█▍        | 37/250 [08:51<48:43, 13.73s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  15%|█▌        | 38/250 [09:06<50:14, 14.22s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  16%|█▌        | 39/250 [09:21<50:57, 14.49s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  16%|█▌        | 40/250 [09:32<46:19, 13.24s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  16%|█▋        | 41/250 [09:47<47:58, 13.77s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  17%|█▋        | 42/250 [10:02<49:15, 14.21s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  17%|█▋        | 43/250 [10:17<50:01, 14.50s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  18%|█▊        | 44/250 [10:32<50:32, 14.72s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  18%|█▊        | 45/250 [10:47<50:51, 14.89s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  18%|█▊        | 46/250 [11:03<51:02, 15.01s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  19%|█▉        | 47/250 [11:18<51:05, 15.10s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  19%|█▉        | 48/250 [11:33<50:58, 15.14s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  20%|█▉        | 49/250 [11:49<50:53, 15.19s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  20%|██        | 50/250 [12:04<50:30, 15.15s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  20%|██        | 51/250 [12:19<50:24, 15.20s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  21%|██        | 52/250 [12:31<47:04, 14.27s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  21%|██        | 53/250 [12:45<46:54, 14.29s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  22%|██▏       | 54/250 [13:01<47:35, 14.57s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  22%|██▏       | 55/250 [13:15<47:19, 14.56s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  22%|██▏       | 56/250 [13:27<44:43, 13.83s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  23%|██▎       | 57/250 [13:39<42:39, 13.26s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  23%|██▎       | 58/250 [13:52<41:31, 12.97s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  24%|██▎       | 59/250 [14:07<43:30, 13.67s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  24%|██▍       | 60/250 [14:21<43:53, 13.86s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  24%|██▍       | 61/250 [14:36<44:55, 14.26s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  25%|██▍       | 62/250 [14:48<42:41, 13.62s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  25%|██▌       | 63/250 [15:04<43:51, 14.07s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  26%|██▌       | 64/250 [15:19<44:45, 14.44s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  26%|██▌       | 65/250 [15:34<45:20, 14.71s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  26%|██▋       | 66/250 [15:47<42:54, 13.99s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  27%|██▋       | 67/250 [16:02<43:58, 14.42s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  27%|██▋       | 68/250 [16:15<42:25, 13.99s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  28%|██▊       | 69/250 [16:30<43:29, 14.42s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  28%|██▊       | 70/250 [16:46<44:09, 14.72s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  28%|██▊       | 71/250 [17:01<44:21, 14.87s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  29%|██▉       | 72/250 [17:13<41:52, 14.12s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  29%|██▉       | 73/250 [17:26<40:33, 13.75s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  30%|██▉       | 74/250 [17:41<41:34, 14.18s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  30%|███       | 75/250 [17:50<36:28, 12.51s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  30%|███       | 76/250 [18:02<35:32, 12.26s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  31%|███       | 77/250 [18:17<37:52, 13.14s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  31%|███       | 78/250 [18:32<39:32, 13.79s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  32%|███▏      | 79/250 [18:48<40:41, 14.28s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  32%|███▏      | 80/250 [19:03<41:27, 14.63s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  32%|███▏      | 81/250 [19:19<41:56, 14.89s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  33%|███▎      | 82/250 [19:30<38:26, 13.73s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  33%|███▎      | 83/250 [19:42<36:45, 13.20s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  34%|███▎      | 84/250 [19:57<38:19, 13.85s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  34%|███▍      | 85/250 [20:12<39:25, 14.34s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  34%|███▍      | 86/250 [20:28<39:58, 14.62s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  35%|███▍      | 87/250 [20:43<40:21, 14.86s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  35%|███▌      | 88/250 [20:54<36:34, 13.55s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  36%|███▌      | 89/250 [21:09<37:45, 14.07s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  36%|███▌      | 90/250 [21:24<38:17, 14.36s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  36%|███▋      | 91/250 [21:36<36:04, 13.61s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  37%|███▋      | 92/250 [21:51<36:56, 14.03s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  37%|███▋      | 93/250 [22:06<37:34, 14.36s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  38%|███▊      | 94/250 [22:19<36:35, 14.07s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  38%|███▊      | 95/250 [22:34<37:07, 14.37s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  38%|███▊      | 96/250 [22:50<37:31, 14.62s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  39%|███▉      | 97/250 [23:05<37:40, 14.77s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  39%|███▉      | 98/250 [23:14<32:57, 13.01s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  40%|███▉      | 99/250 [23:29<34:19, 13.64s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  40%|████      | 100/250 [23:44<35:12, 14.08s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  40%|████      | 101/250 [23:59<35:54, 14.46s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  41%|████      | 102/250 [24:11<33:48, 13.70s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  41%|████      | 103/250 [24:24<33:13, 13.56s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  42%|████▏     | 104/250 [24:40<34:16, 14.09s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  42%|████▏     | 105/250 [24:54<34:21, 14.22s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  42%|████▏     | 106/250 [25:07<32:49, 13.68s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  43%|████▎     | 107/250 [25:22<33:50, 14.20s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  43%|████▎     | 108/250 [25:37<34:25, 14.55s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  44%|████▎     | 109/250 [25:53<34:38, 14.74s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  44%|████▍     | 110/250 [26:05<32:26, 13.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  44%|████▍     | 111/250 [26:20<33:11, 14.33s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  45%|████▍     | 112/250 [26:31<30:51, 13.42s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  45%|████▌     | 113/250 [26:44<29:59, 13.14s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  46%|████▌     | 114/250 [26:59<31:17, 13.81s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  46%|████▌     | 115/250 [27:14<32:02, 14.24s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  46%|████▋     | 116/250 [27:23<28:20, 12.69s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  47%|████▋     | 117/250 [27:39<29:55, 13.50s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  47%|████▋     | 118/250 [27:54<30:46, 13.99s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  48%|████▊     | 119/250 [28:08<30:37, 14.02s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  48%|████▊     | 120/250 [28:23<31:11, 14.40s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  48%|████▊     | 121/250 [28:38<31:30, 14.65s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  49%|████▉     | 122/250 [28:53<31:11, 14.62s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  49%|████▉     | 123/250 [29:07<30:45, 14.53s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  50%|████▉     | 124/250 [29:20<29:11, 13.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  50%|█████     | 125/250 [29:33<28:42, 13.78s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  50%|█████     | 126/250 [29:48<29:17, 14.17s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  51%|█████     | 127/250 [30:03<29:39, 14.47s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  51%|█████     | 128/250 [30:19<29:49, 14.67s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  52%|█████▏    | 129/250 [30:34<29:45, 14.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  52%|█████▏    | 130/250 [30:49<29:48, 14.91s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  52%|█████▏    | 131/250 [31:04<29:34, 14.92s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  53%|█████▎    | 132/250 [31:18<28:52, 14.68s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  53%|█████▎    | 133/250 [31:30<27:01, 13.86s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  54%|█████▎    | 134/250 [31:45<27:34, 14.26s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  54%|█████▍    | 135/250 [31:57<25:56, 13.53s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  54%|█████▍    | 136/250 [32:12<26:38, 14.02s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  55%|█████▍    | 137/250 [32:24<25:02, 13.29s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  55%|█████▌    | 138/250 [32:37<24:44, 13.25s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  56%|█████▌    | 139/250 [32:52<25:43, 13.91s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  56%|█████▌    | 140/250 [33:08<26:22, 14.39s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  56%|█████▋    | 141/250 [33:22<26:04, 14.36s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  57%|█████▋    | 142/250 [33:36<25:53, 14.39s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  57%|█████▋    | 143/250 [33:52<26:06, 14.64s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  58%|█████▊    | 144/250 [34:07<26:04, 14.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  58%|█████▊    | 145/250 [34:22<26:01, 14.88s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  58%|█████▊    | 146/250 [34:37<25:56, 14.97s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  59%|█████▉    | 147/250 [34:52<25:52, 15.08s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  59%|█████▉    | 148/250 [35:06<25:05, 14.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  60%|█████▉    | 149/250 [35:22<25:08, 14.94s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  60%|██████    | 150/250 [35:37<25:03, 15.03s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  60%|██████    | 151/250 [35:52<25:00, 15.16s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  61%|██████    | 152/250 [36:08<24:53, 15.24s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  61%|██████    | 153/250 [36:22<24:15, 15.01s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  62%|██████▏   | 154/250 [36:38<24:07, 15.08s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  62%|██████▏   | 155/250 [36:53<23:57, 15.13s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  62%|██████▏   | 156/250 [37:07<23:00, 14.69s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  63%|██████▎   | 157/250 [37:22<23:05, 14.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  63%|██████▎   | 158/250 [37:37<23:07, 15.08s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  64%|██████▎   | 159/250 [37:52<22:33, 14.87s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  64%|██████▍   | 160/250 [38:03<20:27, 13.64s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  64%|██████▍   | 161/250 [38:18<21:01, 14.17s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  65%|██████▍   | 162/250 [38:31<20:13, 13.80s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  65%|██████▌   | 163/250 [38:46<20:41, 14.27s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  66%|██████▌   | 164/250 [38:57<19:05, 13.32s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  66%|██████▌   | 165/250 [39:11<19:04, 13.47s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  66%|██████▋   | 166/250 [39:25<18:47, 13.43s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  67%|██████▋   | 167/250 [39:39<19:05, 13.80s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  67%|██████▋   | 168/250 [39:54<19:12, 14.05s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  68%|██████▊   | 169/250 [40:07<18:44, 13.89s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  68%|██████▊   | 170/250 [40:21<18:17, 13.72s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  68%|██████▊   | 171/250 [40:33<17:38, 13.40s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  69%|██████▉   | 172/250 [40:49<18:15, 14.04s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  69%|██████▉   | 173/250 [41:04<18:26, 14.37s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  70%|██████▉   | 174/250 [41:19<18:36, 14.69s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  70%|███████   | 175/250 [41:35<18:36, 14.89s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  70%|███████   | 176/250 [41:50<18:29, 14.99s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  71%|███████   | 177/250 [42:02<17:11, 14.13s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  71%|███████   | 178/250 [42:13<15:42, 13.09s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  72%|███████▏  | 179/250 [42:25<15:06, 12.77s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  72%|███████▏  | 180/250 [42:40<15:41, 13.44s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
#   with autocast():
# T5 Validation Epoch 1:  76%|███████▌  | 190/250 [45:05<14:35, 14.59s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  76%|███████▋  | 191/250 [45:18<13:46, 14.02s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  77%|███████▋  | 192/250 [45:31<13:13, 13.69s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  77%|███████▋  | 193/250 [45:42<12:26, 13.10s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  78%|███████▊  | 194/250 [45:58<12:54, 13.83s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  78%|███████▊  | 195/250 [46:13<13:05, 14.29s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  78%|███████▊  | 196/250 [46:29<13:11, 14.65s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  79%|███████▉  | 197/250 [46:42<12:28, 14.12s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  79%|███████▉  | 198/250 [46:57<12:31, 14.45s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  80%|███████▉  | 199/250 [47:12<12:27, 14.65s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  80%|████████  | 200/250 [47:27<12:17, 14.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  80%|████████  | 201/250 [47:42<12:08, 14.87s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  81%|████████  | 202/250 [47:57<11:55, 14.91s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  81%|████████  | 203/250 [48:11<11:30, 14.69s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  82%|████████▏ | 204/250 [48:26<11:20, 14.79s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  82%|████████▏ | 205/250 [48:41<11:11, 14.92s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  82%|████████▏ | 206/250 [48:54<10:20, 14.10s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  83%|████████▎ | 207/250 [49:07<09:54, 13.82s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  83%|████████▎ | 208/250 [49:21<09:44, 13.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  84%|████████▎ | 209/250 [49:36<09:46, 14.30s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  84%|████████▍ | 210/250 [49:48<09:02, 13.56s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  84%|████████▍ | 211/250 [50:03<09:06, 14.02s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  85%|████████▍ | 212/250 [50:15<08:31, 13.45s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  85%|████████▌ | 213/250 [50:27<07:59, 12.97s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  86%|████████▌ | 214/250 [50:39<07:37, 12.70s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  86%|████████▌ | 215/250 [50:51<07:11, 12.32s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  86%|████████▋ | 216/250 [51:06<07:27, 13.15s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  87%|████████▋ | 217/250 [51:21<07:34, 13.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  87%|████████▋ | 218/250 [51:35<07:29, 14.03s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  88%|████████▊ | 219/250 [51:51<07:26, 14.40s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  88%|████████▊ | 220/250 [52:06<07:18, 14.61s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  88%|████████▊ | 221/250 [52:18<06:44, 13.95s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  89%|████████▉ | 222/250 [52:28<05:56, 12.72s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  89%|████████▉ | 223/250 [52:43<06:03, 13.45s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  90%|████████▉ | 224/250 [52:58<06:02, 13.93s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  90%|█████████ | 225/250 [53:13<05:56, 14.27s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  90%|█████████ | 226/250 [53:29<05:50, 14.59s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  91%|█████████ | 227/250 [53:41<05:16, 13.77s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  91%|█████████ | 228/250 [53:55<05:10, 14.10s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  92%|█████████▏| 229/250 [54:10<05:02, 14.40s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  92%|█████████▏| 230/250 [54:26<04:52, 14.61s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  92%|█████████▏| 231/250 [54:41<04:40, 14.76s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  93%|█████████▎| 232/250 [54:56<04:28, 14.91s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  93%|█████████▎| 233/250 [55:09<04:04, 14.36s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  94%|█████████▎| 234/250 [55:22<03:42, 13.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  94%|█████████▍| 235/250 [55:37<03:34, 14.30s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  94%|█████████▍| 236/250 [55:52<03:23, 14.53s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  95%|█████████▍| 237/250 [56:06<03:05, 14.30s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  95%|█████████▌| 238/250 [56:21<02:54, 14.55s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  96%|█████████▌| 239/250 [56:36<02:42, 14.77s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  96%|█████████▌| 240/250 [56:51<02:26, 14.65s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  96%|█████████▋| 241/250 [57:01<01:58, 13.21s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  97%|█████████▋| 242/250 [57:16<01:50, 13.79s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  97%|█████████▋| 243/250 [57:31<01:39, 14.24s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  98%|█████████▊| 244/250 [57:46<01:27, 14.52s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  98%|█████████▊| 245/250 [57:59<01:09, 13.90s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  98%|█████████▊| 246/250 [58:14<00:57, 14.29s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  99%|█████████▉| 247/250 [58:29<00:43, 14.58s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1:  99%|█████████▉| 248/250 [58:44<00:29, 14.81s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1: 100%|█████████▉| 249/250 [59:00<00:14, 14.93s/it]/tmp/ipykernel_31/2906084304.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# T5 Validation Epoch 1: 100%|██████████| 250/250 [59:15<00:00, 14.22s/it]
# T5 Epoch 1 Validation Loss: nan
# T5 Epoch 1 Validation Accuracy: 0.6629
# T5 Epoch 1 Validation Cosine Similarity: 0.1801
#
# Test Example:
# Input: Zapier, the serbice which helps to sync data between web apps through trigger and actions has announced the launch of developer platform.
# T5 Corrected Output: .., the service which helps to sync data between web apps through triggers and actions has announced the launch of developer platform.. Zapier is a web service that helps in syncing data among web applications through. and announcedbice which whichs synchronize data through actions actions actions. announced developer......... of.. Developer platform will help developers to create
# Target: Zapier, the service that helps sync data between web apps through trigger and actions has announced the launch of its developer platform.
